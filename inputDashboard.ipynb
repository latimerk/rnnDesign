# %%
import numpy as np
import matplotlib.pyplot as plt
import rnnDesign.randomMotionStimulus as stim

# %%
aa,bb,cc,dd,tt = stim.generate_temporal_dc(return_parts=True)
plt.plot(tt,aa)
plt.plot(tt,bb)
plt.plot(tt,cc)
plt.plot(tt,dd)
